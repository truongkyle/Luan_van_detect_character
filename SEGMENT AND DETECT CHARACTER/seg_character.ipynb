# %%
from digits import plate_segmentation
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img_file_path = '41.jpg'
img = cv2.imread(img_file_path)
imgray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
digits = plate_segmentation(img_file_path)
plt.imshow(imgray,'gray')
plt.show()

# %%
a = 255 - digits[0]

# %%
plt.imshow(a,'gray')
plt.show()

# %%
from keras.models import load_model
# Out:
# Using TensorFlow backend.
# /home/whoami/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/whoami/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/whoami/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import datetime

# %%
model = load_model('./CNN_1_9_1CNN.hdf5')
# Out:
# WARNING:tensorflow:From /home/whoami/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/whoami/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
a = a.reshape(1,28,28,1)
c = datetime.datetime.now()
predict = model.predict(a)
d = datetime.datetime.now()
e = d -c
print(str(e.total_seconds()))
# Out:
# 0.138403

# %%
print(np.argmax(predict))
print(predict)
# Out:
# 7
# [[5.1230669e-05 1.4739055e-03 4.1262654e-04 5.0782568e-05 1.1630204e-05
#   1.0194495e-05 2.3434930e-06 9.9793565e-01 1.7580340e-05 3.4013101e-05]]

# %%
start_time = datetime.datetime.now()

img_file_path = '41.jpg'
img = cv2.imread(img_file_path)
imgray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
digits = plate_segmentation(img_file_path)

for digit in digits:
    img_predict = 255 - digit
    plt.imshow(img_predict,'gray')
    plt.show()
    img_predict = img_predict.reshape(1,28,28,1)
    predict = model.predict(img_predict)
    print(np.argmax(predict))
end_time =  datetime.datetime.now()
e = end_time -start_time
print(str(e.total_seconds())
# Out:
# 7
# 4
# 8
# 6
# 5
# 1
# 8
# 9
# 5
# 2.617984

# %%
print(e)
# Out:
# 0:00:02.617984
